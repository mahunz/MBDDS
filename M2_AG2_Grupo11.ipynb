# %% [markdown]
# <a href="https://colab.research.google.com/github/mahunz/MDBDS_M2/blob/main/M2_AG2_Grupo11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1> Estadistica Descriptiva </h1>
# <h3>M2_AG1_Predicción_Ventas</h3>
# <h3>Alumnos:
#
# *   Paola Nieto Vives
# *   Martín Hunziker
#  </h3>

# %% [markdown]
# ### Librerias

# %%
import pandas as pd
import numpy as np
from functools import reduce
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns; sns.set()  # para el estilo de graficos
import math
import scipy.stats as ss

sns.set_theme(style="darkgrid")

# %%
to

# %% [markdown]
# ### Lectura de los datos y Análisis de las variables del dataset
#
# Leemos el archivo datos ventas.csv desde github y visualizamos la cabezera

# %%
# Carga del fichero desde el enlace web y creación del dataframe
url = 'https://raw.githubusercontent.com/md-lorente/data/master/datos_ventas.csv'

# Creación del Dataframe
DS_Ventas = pd.read_csv(url,sep = ';', decimal = ',')

# Visualización del dataframe (la cabecera)
DS_Ventas.head()
# Out:
#    Fecha_anual  Inversion  Ventas
# 0         1980        1.0    4.61
# 1         1981        1.5    5.18
# 2         1982        2.0    5.09
# 3         1983        2.5    5.44
# 4         1984        3.0    0.62

# %%
# Resumen información del dataframe
print(DS_Ventas.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Fecha_anual  38 non-null     int64
#  1   Inversion    38 non-null     float64
#  2   Ventas       38 non-null     float64
# dtypes: float64(2), int64(1)
# memory usage: 1.0 KB
# None

# %%
# Contando los valores  NaN en todas las columnas
nan_count = DS_Ventas.isna().sum()

print(nan_count)
# Out:
# Fecha_anual    0
# Inversion      0
# Ventas         0
# dtype: int64

# %% [markdown]
# Como el dataset no tiene valores nulos, no será necesario realizar un tratamiento en los datos para poder calcular los estadísticos y esto aportará fiabilidad a las conclusiones obtenidas.

# %%
# Analizamos los datos
DS_Ventas.describe()
# Out:
#        Fecha_anual  Inversion     Ventas
# count    38.000000  38.000000  38.000000
# mean   1998.500000  10.250000  10.492895
# std      11.113055   5.556528   4.315321
# min    1980.000000   1.000000   0.620000
# 25%    1989.250000   5.625000   7.565000
# 50%    1998.500000  10.250000  11.080000
# 75%    2007.750000  14.875000  14.032500
# max    2017.000000  19.500000  17.450000

# %% [markdown]
# El tipo de variables del dataset es:
#
# 1. **Fecha_anual** es la año en el cual se totalizaron las ventas y las inversiones del data set. Como no tiene sentido sumar literalmente las fechas. Es una variable: **cualitativa ordinal**.
#
# 2. **Inversion** Es el monto de la inversión realizada en el año de referencia. Es una variable **cuantitativa continua** porque podría tener infinitos valores.
#
# 3. **Ventas** Es el monto de las ventas realizada en el año de referencia. **variable cuantitativa continua** porque podría tener infinitos valores  .

# %% [markdown]
# ### Necesitáis realizar las siguientes tareas:
#
# 1.   Ajustar un modelo de regresión lineal (esto implica escribir la fórmula y su sustitución). Obtener una estimación de los parámetros del modelo y la interpretación de los parámetros. (85%)
# 2.   ¿Cuántas ventas se obtendrían si se invirtiesen 7 millones de euros? (10%)
# 3. Evaluar el modelo a través de la SCE y el coeficiente de determinación. (5%)
